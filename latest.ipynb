# %% [markdown]
# # code for task a in a single cell

# %%
import numpy as np

# %%
# %%time

import pandas as pd
import matplotlib.pyplot as plt
import time

trips = pd.read_csv("Trips_by_Distance.csv")
trips['Date'] = pd.to_datetime(trips['Date'])
#sort by date, not needed
trips = trips.sort_values(by='Date', ascending=True)

#remove unneccessary columns
trips = trips.drop(columns=["State FIPS", "State Postal Code", "County FIPS", "County Name"])


#Look for data in the national level only
trips__national = trips[trips["Level"] == "National"]
national_mean_home_pop = trips__national.groupby(by='Week')['Population Staying at Home'].mean()


plt.figure(figsize = (17, 10))
national_mean_home_pop.plot(kind='bar', color='skyblue')


plt.title('National Mean Population Staying at Home by Week')
plt.xlabel('Week')
plt.ylabel('Mean Population Staying at Home')
plt.xticks(rotation=90)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:13
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6569, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6566     mask = count >= thresh
#    6567 elif how == "any":
#    6568     # faster equivalent to 'agg_obj.count(agg_axis) == self.shape[agg_axis]'
# -> 6569     mask = notna(agg_obj).all(axis=agg_axis, bool_only=False)
#    6570 elif how == "all":
#    6571     # faster equivalent to 'agg_obj.count(agg_axis) > 0'
#    6572     mask = notna(agg_obj).any(axis=agg_axis, bool_only=False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:434, in notna(obj)
#     357 def notna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     358     """
#     359     Detect non-missing values for an array-like object.
#     360
#    (...)
#     432     Name: 1, dtype: bool
#     433     """
# --> 434     res = isna(obj)
#     435     if isinstance(res, bool):
#     436         return not res
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:185, in isna(obj)
#     108 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     109     """
#     110     Detect missing values for an array-like object.
#     111
#    (...)
#     183     Name: 1, dtype: bool
#     184     """
# --> 185     return _isna(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:228, in _isna(obj, inf_as_na)
#     226     return result
#     227 elif isinstance(obj, ABCDataFrame):
# --> 228     return obj.isna()
#     229 elif isinstance(obj, list):
#     230     return _isna_array(np.asarray(obj, dtype=object), inf_as_na=inf_as_na)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6379, in DataFrame.isna(self)
#    6377 @doc(NDFrame.isna, klass=_shared_doc_kwargs["klass"])
#    6378 def isna(self) -> DataFrame:
# -> 6379     result = self._constructor(self._mgr.isna(func=isna))
#    6380     return result.__finalize__(self, method="isna")
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\base.py:143, in DataManager.isna(self, func)
#     141 @final
#     142 def isna(self: T, func) -> T:
# --> 143     return self.apply("apply", func=func)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:351, in Block.apply(self, func, **kwargs)
#     345 @final
#     346 def apply(self, func, **kwargs) -> list[Block]:
#     347     """
#     348     apply the function to my values; return a block if we are not
#     349     one
#     350     """
# --> 351     result = func(self.values, **kwargs)
#     353     return self._split_op_result(result)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:185, in isna(obj)
#     108 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     109     """
#     110     Detect missing values for an array-like object.
#     111
#    (...)
#     183     Name: 1, dtype: bool
#     184     """
# --> 185     return _isna(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:214, in _isna(obj, inf_as_na)
#     212     return False
#     213 elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 214     return _isna_array(obj, inf_as_na=inf_as_na)
#     215 elif isinstance(obj, ABCIndex):
#     216     # Try to use cached isna, which also short-circuits for integer dtypes
#     217     #  and avoids materializing RangeIndex._values
#     218     if not obj._can_hold_na:
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:304, in _isna_array(values, inf_as_na)
#     302         result = ~np.isfinite(values)
#     303     else:
# --> 304         result = np.isnan(values)
#     306 return result
#
# KeyboardInterrupt:

# %%
trips.max()
# Out:
# Level                                           State
# Date                              2022-02-06 00:00:00
# Population Staying at Home                110211784.0
# Population Not Staying at Home            273739951.0
# Number of Trips                          1569052522.0
# Number of Trips <1                        422700184.0
# Number of Trips 1-3                       405130498.0
# Number of Trips 3-5                       198018442.0
# Number of Trips 5-10                      252611815.0
# Number of Trips 10-25                     256509626.0
# Number of Trips 25-50                      76367324.0
# Number of Trips 50-100                     28735606.0
# Number of Trips 100-250                    14476977.0
# Number of Trips 250-500                     3651375.0
# Number of Trips >=500                       5003062.0
# Row ID                              56-56045-20210619
# Week                                               52
# Month                                              12
# dtype: object

# %%
# plt.figure(figsize = (17, 10))

# national_mean_home_pop.plot(kind='bar', color='skyblue')

# # Set title, x-label, and y-label
# plt.title('National Mean Population Staying at Home by Week')
# plt.xlabel('Week')
# plt.ylabel('Mean Population Staying at Home')
# plt.xticks(rotation=90)
# # plt.grid(axis='both')

# # Show the plot
# plt.show()

# %%
national_mean_home_pop
# Out:
# Week
# 0     7.384405e+07
# 1     7.222715e+07
# 2     7.144295e+07
# 3     6.998493e+07
# 4     6.982941e+07
# 5     6.910108e+07
# 6     6.852736e+07
# 7     7.001310e+07
# 8     6.587532e+07
# 9     6.563279e+07
# 10    6.598210e+07
# 11    7.366140e+07
# 12    7.478372e+07
# 13    7.577730e+07
# 14    7.568128e+07
# 15    7.616011e+07
# 16    7.425262e+07
# 17    7.430106e+07
# 18    7.402338e+07
# 19    7.113875e+07
# 20    6.735490e+07
# 21    7.148468e+07
# 22    7.073767e+07
# 23    7.030620e+07
# 24    7.118134e+07
# 25    6.993038e+07
# 26    7.264797e+07
# 27    7.115585e+07
# 28    7.149897e+07
# 29    7.425933e+07
# 30    7.335349e+07
# 31    7.199460e+07
# 32    6.848695e+07
# 33    6.834164e+07
# 34    7.134600e+07
# 35    7.371997e+07
# 36    7.447109e+07
# 37    7.402661e+07
# 38    7.317520e+07
# 39    7.379786e+07
# 40    7.488744e+07
# 41    7.417908e+07
# 42    7.444592e+07
# 43    7.545111e+07
# 44    7.847537e+07
# 45    8.025509e+07
# 46    8.030774e+07
# 47    8.110965e+07
# 48    7.824118e+07
# 49    7.909777e+07
# 50    7.997042e+07
# 51    8.488364e+07
# 52    8.473824e+07
# Name: Population Staying at Home, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

trips = pd.read_csv("Trips_by_Distance.csv")
trips_full = pd.read_csv("Trips_Full Data.csv")
trips['Date'] = pd.to_datetime(trips['Date'])

# %%
trips['Number of Trips 100-250'].mean()
# Out:
# 15824.533751116476

# %%
trips[trips['Level'] == 'National'].isnull().any()
# Out:
# Level                             False
# Date                              False
# State FIPS                         True
# State Postal Code                  True
# County FIPS                        True
# County Name                        True
# Population Staying at Home        False
# Population Not Staying at Home    False
# Number of Trips                   False
# Number of Trips <1                False
# Number of Trips 1-3               False
# Number of Trips 3-5               False
# Number of Trips 5-10              False
# Number of Trips 10-25             False
# Number of Trips 25-50             False
# Number of Trips 50-100            False
# Number of Trips 100-250           False
# Number of Trips 250-500           False
# Number of Trips >=500             False
# Row ID                            False
# Week                              False
# Month                             False
# dtype: bool

# %%
trips.head()
# Out:
#       Level       Date  State FIPS State Postal Code  County FIPS County Name  \
# 0  National 2019-01-01         NaN               NaN          NaN         NaN
# 1  National 2019-01-02         NaN               NaN          NaN         NaN
# 2  National 2019-01-03         NaN               NaN          NaN         NaN
# 3  National 2019-01-04         NaN               NaN          NaN         NaN
# 4  National 2019-01-05         NaN               NaN          NaN         NaN
#
#    Population Staying at Home  Population Not Staying at Home  \
# 0                  77433867.0                     248733553.0
# 1                  61305201.0                     264862219.0
# 2                  63050480.0                     263116940.0
# 3                  61803652.0                     264363768.0
# 4                  64389745.0                     261777675.0
#
#    Number of Trips  Number of Trips <1  Number of Trips 1-3  \
# 0     8.977844e+08         241667151.0          234284795.0
# 1     1.139452e+09         291276735.0          285887315.0
# 2     1.162753e+09         296375014.0          290074425.0
# 3     1.181954e+09         293159631.0          295643296.0
# 4     1.180477e+09         295459014.0          304168709.0
#
#    Number of Trips 3-5  Number of Trips 5-10  Number of Trips 10-25  \
# 0          108078903.0           129670778.0            116904343.0
# 1          138039296.0           171637514.0            167412698.0
# 2          140771581.0           175775410.0            172027487.0
# 3          145251819.0           181324645.0            176144493.0
# 4          148540651.0           180941769.0            165239790.0
#
#    Number of Trips 25-50  Number of Trips 50-100  Number of Trips 100-250  \
# 0             40432062.0              15686639.0                7525563.0
# 1             56148976.0              17739183.0                7817044.0
# 2             57632422.0              18366626.0                8124548.0
# 3             58761592.0              19315785.0                8687318.0
# 4             54842134.0              19363939.0                8490791.0
#
#    Number of Trips 250-500  Number of Trips >=500             Row ID  Week  \
# 0                1806022.0              1728112.0  00-00000-20190101     0
# 1                1962301.0              1531219.0  00-00000-20190102     0
# 2                2038099.0              1567072.0  00-00000-20190103     0
# 3                2096065.0              1569185.0  00-00000-20190104     0
# 4                1991159.0              1438664.0  00-00000-20190105     0
#
#    Month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
trips.dtypes
# Out:
# Level                                     object
# Date                              datetime64[ns]
# State FIPS                               float64
# State Postal Code                         object
# County FIPS                              float64
# County Name                               object
# Population Staying at Home               float64
# Population Not Staying at Home           float64
# Number of Trips                          float64
# Number of Trips <1                       float64
# Number of Trips 1-3                      float64
# Number of Trips 3-5                      float64
# Number of Trips 5-10                     float64
# Number of Trips 10-25                    float64
# Number of Trips 25-50                    float64
# Number of Trips 50-100                   float64
# Number of Trips 100-250                  float64
# Number of Trips 250-500                  float64
# Number of Trips >=500                    float64
# Row ID                                    object
# Week                                       int64
# Month                                      int64
# dtype: object

# %%
trips.isnull().any()
# Out:
# Level                             False
# Date                              False
# State FIPS                         True
# State Postal Code                  True
# County FIPS                        True
# County Name                        True
# Population Staying at Home         True
# Population Not Staying at Home     True
# Number of Trips                    True
# Number of Trips <1                 True
# Number of Trips 1-3                True
# Number of Trips 3-5                True
# Number of Trips 5-10               True
# Number of Trips 10-25              True
# Number of Trips 25-50              True
# Number of Trips 50-100             True
# Number of Trips 100-250            True
# Number of Trips 250-500            True
# Number of Trips >=500              True
# Row ID                            False
# Week                              False
# Month                             False
# dtype: bool

# %%
# Find the row with missing value in "Number of Trips 5-10" column
missing_row = trips[trips["Number of Trips 5-10"].isnull()].iloc[66]

# Display the entire row
print("Row with missing value in 'Number of Trips 5-10' column:")
print(missing_row)
# Out:
# Row with missing value in 'Number of Trips 5-10' column:
# Level                                          County
# Date                              2019-01-04 00:00:00
# State FIPS                                       31.0
# State Postal Code                                  NE
# County FIPS                                   31171.0
# County Name                             Thomas County
# Population Staying at Home                        NaN
# Population Not Staying at Home                    NaN
# Number of Trips                                   NaN
# Number of Trips <1                                NaN
# Number of Trips 1-3                               NaN
# Number of Trips 3-5                               NaN
# Number of Trips 5-10                              NaN
# Number of Trips 10-25                             NaN
# Number of Trips 25-50                             NaN
# Number of Trips 50-100                            NaN
# Number of Trips 100-250                           NaN
# Number of Trips 250-500                           NaN
# Number of Trips >=500                             NaN
# Row ID                              31-31171-20190104
# Week                                                0
# Month                                               1
# Name: 58714, dtype: object

# %%
missing_rows_df = trips[trips["Number of Trips 5-10"].isnull()]
missing_rows_df
# Out:
#           Level       Date  State FIPS State Postal Code  County FIPS  \
# 46154    County 2019-01-01        48.0                TX      48269.0
# 46155    County 2019-01-01         2.0                AK       2164.0
# 46159    County 2019-01-01         2.0                AK       2282.0
# 46160    County 2019-01-01         2.0                AK       2230.0
# 46161    County 2019-01-01        31.0                NE      31005.0
# ...         ...        ...         ...               ...          ...
# 1048397  County 2019-11-12        53.0                WA      53069.0
# 1048460  County 2019-11-12         2.0                AK       2282.0
# 1048492  County 2019-11-12         2.0                AK       2290.0
# 1048515  County 2019-11-03        30.0                MT      30055.0
# 1048525  County 2019-11-12         6.0                CA       6003.0
#
#                         County Name  Population Staying at Home  \
# 46154                   King County                         NaN
# 46155    Lake and Peninsula Borough                         NaN
# 46159      Yakutat City and Borough                         NaN
# 46160          Skagway Municipality                         NaN
# 46161                 Arthur County                         NaN
# ...                             ...                         ...
# 1048397            Wahkiakum County                         NaN
# 1048460    Yakutat City and Borough                         NaN
# 1048492   Yukon-Koyukuk Census Area                         NaN
# 1048515               McCone County                         NaN
# 1048525               Alpine County                         NaN
#
#          Population Not Staying at Home  Number of Trips  Number of Trips <1  \
# 46154                               NaN              NaN                 NaN
# 46155                               NaN              NaN                 NaN
# 46159                               NaN              NaN                 NaN
# 46160                               NaN              NaN                 NaN
# 46161                               NaN              NaN                 NaN
# ...                                 ...              ...                 ...
# 1048397                             NaN              NaN                 NaN
# 1048460                             NaN              NaN                 NaN
# 1048492                             NaN              NaN                 NaN
# 1048515                             NaN              NaN                 NaN
# 1048525                             NaN              NaN                 NaN
#
#          Number of Trips 1-3  Number of Trips 3-5  Number of Trips 5-10  \
# 46154                    NaN                  NaN                   NaN
# 46155                    NaN                  NaN                   NaN
# 46159                    NaN                  NaN                   NaN
# 46160                    NaN                  NaN                   NaN
# 46161                    NaN                  NaN                   NaN
# ...                      ...                  ...                   ...
# 1048397                  NaN                  NaN                   NaN
# 1048460                  NaN                  NaN                   NaN
# 1048492                  NaN                  NaN                   NaN
# 1048515                  NaN                  NaN                   NaN
# 1048525                  NaN                  NaN                   NaN
#
#          Number of Trips 10-25  Number of Trips 25-50  Number of Trips 50-100  \
# 46154                      NaN                    NaN                     NaN
# 46155                      NaN                    NaN                     NaN
# 46159                      NaN                    NaN                     NaN
# 46160                      NaN                    NaN                     NaN
# 46161                      NaN                    NaN                     NaN
# ...                        ...                    ...                     ...
# 1048397                    NaN                    NaN                     NaN
# 1048460                    NaN                    NaN                     NaN
# 1048492                    NaN                    NaN                     NaN
# 1048515                    NaN                    NaN                     NaN
# 1048525                    NaN                    NaN                     NaN
#
#          Number of Trips 100-250  Number of Trips 250-500  \
# 46154                        NaN                      NaN
# 46155                        NaN                      NaN
# 46159                        NaN                      NaN
# 46160                        NaN                      NaN
# 46161                        NaN                      NaN
# ...                          ...                      ...
# 1048397                      NaN                      NaN
# 1048460                      NaN                      NaN
# 1048492                      NaN                      NaN
# 1048515                      NaN                      NaN
# 1048525                      NaN                      NaN
#
#          Number of Trips >=500             Row ID  Week  Month
# 46154                      NaN  48-48269-20190101     0      1
# 46155                      NaN  02-02164-20190101     0      1
# 46159                      NaN  02-02282-20190101     0      1
# 46160                      NaN  02-02230-20190101     0      1
# 46161                      NaN  31-31005-20190101     0      1
# ...                        ...                ...   ...    ...
# 1048397                    NaN  53-53069-20191112    45     11
# 1048460                    NaN  02-02282-20191112    45     11
# 1048492                    NaN  02-02290-20191112    45     11
# 1048515                    NaN  30-30055-20191103    44     11
# 1048525                    NaN  06-06003-20191112    45     11
#
# [12950 rows x 22 columns]

# %%
trips_filtered = trips.drop(columns=["State FIPS", "State Postal Code", "County FIPS", "County Name"])

trips_filtered.head()

trips_filtered.shape
# Out:
# (1048575, 18)

# %%
trips_filtered.dropna(inplace=True)

trips_filtered.shape
# Out:
# (1035625, 18)

# %%
#check if the correct data types are in each column
trips_filtered.info()

#How far are people traveling when they don’t stay home?

trips_full.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1035625 entries, 0 to 1048574
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Level                           1035625 non-null  object
#  1   Date                            1035625 non-null  datetime64[ns]
#  2   Population Staying at Home      1035625 non-null  float64
#  3   Population Not Staying at Home  1035625 non-null  float64
#  4   Number of Trips                 1035625 non-null  float64
#  5   Number of Trips <1              1035625 non-null  float64
#  6   Number of Trips 1-3             1035625 non-null  float64
#  7   Number of Trips 3-5             1035625 non-null  float64
#  8   Number of Trips 5-10            1035625 non-null  float64
#  9   Number of Trips 10-25           1035625 non-null  float64
#  10  Number of Trips 25-50           1035625 non-null  float64
#  11  Number of Trips 50-100          1035625 non-null  float64
#  12  Number of Trips 100-250         1035625 non-null  float64
#  13  Number of Trips 250-500         1035625 non-null  float64
#  14  Number of Trips >=500           1035625 non-null  float64
#  15  Row ID                          1035625 non-null  object
#  16  Week                            1035625 non-null  int64
#  17  Month                           1035625 non-null  int64
# dtypes: datetime64[ns](1), float64(13), int64(2), object(2)
# memory usage: 150.1+ MB
#   Month of Date Week of Date  Year of Date     Level           Date  \
# 0        August      Week 32          2019  National  8/4/2019 0:00
# 1        August      Week 32          2019  National  8/5/2019 0:00
# 2        August      Week 32          2019  National  8/6/2019 0:00
# 3        August      Week 32          2019  National  8/7/2019 0:00
# 4        August      Week 32          2019  National  8/8/2019 0:00
#
#   Week Ending Date  Trips <1 Mile  People Not Staying at Home  \
# 0        10-Aug-19      292959749                   258404133
# 1        10-Aug-19      317133861                   262199758
# 2        10-Aug-19      324443205                   260096133
# 3        10-Aug-19      358483024                   258878802
# 4        10-Aug-19      300765870                   262410045
#
#    Population Staying at Home       Trips  Trips 1-25 Miles  Trips 1-3 Miles  \
# 0                    67763287  1322685497         934957837        346577279
# 1                    63967662  1412564488         996863262        358008909
# 2                    66071287  1437762102        1014614495        366533991
# 3                    67288618  1543710309        1084498325        401474049
# 4                    63757375  1382044815         984193010        347857770
#
#    Trips 10-25 Miles  Trips 100-250 Miles  Trips 100+ Miles  \
# 0          200922270              8595827          15338786
# 1          228809869              6535920          12563068
# 2          235621127              5993704          11104823
# 3          249988663              5379881           8528574
# 4          226055368              6259735          12892348
#
#    Trips 25-100 Miles  Trips 25-50 Miles  Trips 250-500 Miles  \
# 0            79429125           59517188              2273613
# 1            86004297           68184743              1941260
# 2            87599579           70149166              1741994
# 3            92200386           74381367              1272248
# 4            84193587           66724543              1957888
#
#    Trips 3-5 Miles  Trips 5-10 Miles  Trips 50-100 Miles  Trips 500+ Miles
# 0        171336406         216121882            19911937           4469346
# 1        178996059         231048425            17819554           4085888
# 2        179210645         233248732            17450413           3369125
# 3        189163336         243872277            17819019           1876445
# 4        179346163         230933709            17469044           4674725

# %%
# Check the first and last date
first_date = trips_filtered['Date'].min()
last_date = trips_filtered['Date'].max()

# Display the first and last date
print("First date:", first_date)
print("Last date:", last_date)
# Out:
# First date: 2019-01-01 00:00:00
# Last date: 2022-02-06 00:00:00

# %%
#sort by date
trips_filtered = trips_filtered.sort_values(by='Date', ascending=True)

trips_filtered['Level'].value_counts()

trips_filtered_national = trips_filtered[trips_filtered["Level"] == "National"]
trips_filtered_state = trips_filtered[trips_filtered["Level"] == "State"]
trips_filtered_county = trips_filtered[trips_filtered["Level"] == "County"]

# %%
# Group by 'Week' and calculate the mean of 'Population Staying at Home'
mean_population_at_home_national = trips_filtered_national.groupby(by='Week')['Population Staying at Home'].mean()
mean_population_at_home_state = trips_filtered_state.groupby(by='Week')['Population Staying at Home'].mean()
mean_population_at_home_county = trips_filtered_county.groupby(by='Week')['Population Staying at Home'].mean()
mean_population_at_home = trips_filtered_county['Population Staying at Home'].mean()

# %%
mean_population_at_home
# Out:
# 20295.15033278619

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 18))




# Plot national data
mean_population_at_home_national.plot(kind='bar', ax=axes[0], color='skyblue')
axes[0].set_title('National Mean Population Staying at Home by Week')
axes[0].set_xlabel('Week')
axes[0].set_ylabel('Mean Population Staying at Home')
axes[0].tick_params(axis='x', rotation=90)
axes[0].grid(axis='y')

# Plot state data
mean_population_at_home_state.plot(kind='bar', ax=axes[1], color='orange')
axes[1].set_title('State Mean Population Staying at Home by Week')
axes[1].set_xlabel('Week')
axes[1].set_ylabel('Mean Population Staying at Home')
axes[1].tick_params(axis='x', rotation=90)
axes[1].grid(axis='y')

# Plot county data
mean_population_at_home_county.plot(kind='bar', ax=axes[2], color='green')
axes[2].set_title('County Mean Population Staying at Home by Week')
axes[2].set_xlabel('Week')
axes[2].set_ylabel('Mean Population Staying at Home')
axes[2].tick_params(axis='x', rotation=90)
axes[2].grid(axis='y')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
#consider dropping the county level week 44, data may be incomplete

# %%
national_trips_filtered = trips_filtered[trips_filtered['Level'] == 'National']

# %% [markdown]
# # How far people travel when they don't stay home

# %%
trips_full
# Out:
#   Month of Date Week of Date  Year of Date     Level            Date  \
# 0        August      Week 32          2019  National   8/4/2019 0:00
# 1        August      Week 32          2019  National   8/5/2019 0:00
# 2        August      Week 32          2019  National   8/6/2019 0:00
# 3        August      Week 32          2019  National   8/7/2019 0:00
# 4        August      Week 32          2019  National   8/8/2019 0:00
# 5        August      Week 32          2019  National   8/9/2019 0:00
# 6        August      Week 32          2019  National  8/10/2019 0:00
#
#   Week Ending Date  Trips <1 Mile  People Not Staying at Home  \
# 0        10-Aug-19      292959749                   258404133
# 1        10-Aug-19      317133861                   262199758
# 2        10-Aug-19      324443205                   260096133
# 3        10-Aug-19      358483024                   258878802
# 4        10-Aug-19      300765870                   262410045
# 5        10-Aug-19      341515854                   272101417
# 6        10-Aug-19      346532975                   267638064
#
#    Population Staying at Home       Trips  Trips 1-25 Miles  Trips 1-3 Miles  \
# 0                    67763287  1322685497         934957837        346577279
# 1                    63967662  1412564488         996863262        358008909
# 2                    66071287  1437762102        1014614495        366533991
# 3                    67288618  1543710309        1084498325        401474049
# 4                    63757375  1382044815         984193010        347857770
# 5                    54066003  1501571863        1052793819        378936486
# 6                    58529356  1491503216        1040967509        386948113
#
#    Trips 10-25 Miles  Trips 100-250 Miles  Trips 100+ Miles  \
# 0          200922270              8595827          15338786
# 1          228809869              6535920          12563068
# 2          235621127              5993704          11104823
# 3          249988663              5379881           8528574
# 4          226055368              6259735          12892348
# 5          245571995              7635743          12256537
# 6          230580285              7550100          12173176
#
#    Trips 25-100 Miles  Trips 25-50 Miles  Trips 250-500 Miles  \
# 0            79429125           59517188              2273613
# 1            86004297           68184743              1941260
# 2            87599579           70149166              1741994
# 3            92200386           74381367              1272248
# 4            84193587           66724543              1957888
# 5            95005653           74512584              1823661
# 6            91829556           70644329              1794030
#
#    Trips 3-5 Miles  Trips 5-10 Miles  Trips 50-100 Miles  Trips 500+ Miles
# 0        171336406         216121882            19911937           4469346
# 1        178996059         231048425            17819554           4085888
# 2        179210645         233248732            17450413           3369125
# 3        189163336         243872277            17819019           1876445
# 4        179346163         230933709            17469044           4674725
# 5        186257669         242027669            20493069           2797133
# 6        186580557         236858554            21185227           2829046

# %%
trips_full['People Not Staying at Home']
# Out:
# 0    258404133
# 1    262199758
# 2    260096133
# 3    258878802
# 4    262410045
# 5    272101417
# 6    267638064
# Name: People Not Staying at Home, dtype: int64

# %%
plt.plot(trips_full['People Not Staying at Home'], trips_full['People Not Staying at Home'])

# %%
all_distances_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 all_distances_mean
#
# NameError: name 'all_distances_mean' is not defined

# %%
not_home_mean  =  trips_full.groupby(by = 'Week')['Trips 1-25 Miles'].mean()

# %%
all_distances_mean = pd.DataFrame(trips_full.iloc[:, 10:].mean())

# %%
all_distances_mean

# %%
all_distances_mean.columns = ['distance']
all_distances_mean

# %%
pd.DataFrame(all_distances_mean)

# %%
all_distances_mean

# %%
trips_full.iloc[:1, 10:]

# %%
trips_full.iloc[0, 10:].sum()

# %%
258404133
2059451496
1322685497

# %%
trips_full

# %%
trips_full.nunique()

# %%
trips_filtered['Week'].nunique()
#group the average Population Staying at Home per month
trips_filtered.groupby(by = 'Week')['Population Staying at Home'].mean()




# How far are people traveling when they don’t stay home?

trips_full.rename(columns={'Week of Date': 'Week'}, inplace=True)

columns_to_process = ['Trips 1-25 Miles', 'Trips 1-3 Miles', 'Trips 10-25 Miles', 
                      'Trips 100-250 Miles', 'Trips 100+ Miles', 'Trips 25-100 Miles', 
                      'Trips 25-50 Miles', 'Trips 250-500 Miles', 'Trips 3-5 Miles', 
                      'Trips 5-10 Miles', 'Trips 50-100 Miles', 'Trips 500+ Miles']

# %%
# Iterate over each column and apply the code
for column in columns_to_process:
    # Calculate the number of unique values
    unique_count = trips_full[column].nunique()
    print(f"Number of unique values in '{column}': {unique_count}")
    
    # Group by 'Week of Date' and calculate the mean of the column
    mean_by_week = trips_full.groupby(by='Week')[column].mean()
    print(f"Mean of '{column}' by 'Week':\n{mean_by_week}\n")

trips_full.head()

# %%
trips_full.groupby(by = 'Week')['Trips 1-25 Miles'].mean()

trips_full_distance = trips_full.iloc[:, 9:]
trips_full_distance = trips_full_distance.drop(columns=['Trips'])
trips_full_distance

plt.figure(figsize=(12, 8))
trips_full_distance.mean().plot(kind = "bar",color = "red")
plt.title('Average Number of Trips by Distance')
plt.xlabel('Average distance of Trips')
plt.ylabel('Number of trips ')
plt.tight_layout()
plt.show()

# %%
pd.DataFrame(trips_full.groupby(by = 'Week'))

# %%
trips_full.groupby(by = 'Week')['Trips 1-25 Miles'].mean()

# %%
trips_full_distance.mean()

# %%
trips_full.groupby(by = 'Week')['Trips 1-25 Miles'].mean()

# %%
trips_full

# %% [markdown]
# # Identify the dates that > 10000000 people conducted 10-25 Number of Trips and compare them to them that the same number of people (> 10000000) conducted 50-100 Number of trips.

# %%
trips_1025_national = trips_filtered[(trips_filtered['Number of Trips 10-25'] > 10000000) & 
                                     (trips_filtered['Level'] == 'National')]

# %%
trips_1025 = trips_filtered[(trips_filtered['Number of Trips 10-25'] > 10000000) & 
                                     (trips_filtered['Level'] == 'National')]
trips_50100 = trips_filtered[(trips_filtered['Number of Trips 50-100'] > 10000000) & 
                                     (trips_filtered['Level'] == 'National')]

#date already datetime

# plt.figure(figsize=(10, 5))
# plt.scatter(trips_1025['Date'], trips_1025['Number of Trips 10-25'], color='blue', label='Trips 10-25 Miles')
# plt.title('Number of Trips (10-25 Miles) Over Time')
# plt.xlabel('Date')
# plt.ylabel('Number of Trips')
# plt.legend()
# plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(trips_50100['Date'], trips_50100['Number of Trips 50-100'], color='green')
plt.title('Number of Trips (50-100 Miles) Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Trips')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(trips_1025['Date'], trips_1025['Number of Trips 10-25'], color='blue', label='Trips 10-25 Miles')
plt.yscale('log')  # Apply logarithmic scale
plt.title('Number of Trips (10-25 Miles) Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Trips (Log Scale)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import plotly.express as px

# %%
 px.scatter(x= trips_1025["Date"], y= trips_1025['Number of Trips 10-25'])

# %% [markdown]
# # dask

# %%
trips['Number of Trips 100-250'].mean()
